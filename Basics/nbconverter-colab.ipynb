# %% [markdown]
# ## A Simple Notebook for Generating PDFs from ipynb in Colab
# ### Usage:
#     1) Replace the <notebookname> with actual notebook name inside your google drive
#     2) Run the notebook, you would see a pdf file generated next to the specified notebook

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !apt-get update >> /dev/null && apt-get install texlive-xetex texlive-fonts-recommended texlive-generic-recommended >> /dev/null

# %%
# !jupyter nbconvert "drive/MyDrive/Colab Notebooks/<notebookname>.ipynb" --to pdf
